# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

data = np.load("data.npy",allow_pickle=True)

# %%
data
# Out:
# array([[ 93,  93,  95, ...,  73,  67,   0],
#        [ 23,  33,  21, ..., 134, 153,   0],
#        [157, 156, 156, ..., 109, 112,   0],
#        ...,
#        [123, 125, 129, ..., 126, 126,   0],
#        [ 47,  68,  81, ...,  74,  65,   0],
#        [188, 195, 188, ...,  60,  66,   0]], dtype=uint8)

# %%
data.shape
# Out:
# (1043, 2501)

# %% [markdown]
# Last Column of data is y, others are X, total 1043 images, other columns are flatten 50*50 image data

# %%
X = data[:,:-1]
y = data[:,-1]

np.unique(y,return_counts=True)
# Out:
# (array([0, 1], dtype=uint8), array([509, 534]))

# %%
def get_photo(X):
    X = X.reshape(50,50)
    image = Image.fromarray(X)

    plt.imshow(image,cmap="gray")

# %% [markdown]
# 534 are butterflay 509 are tree photos

# %%
SAMPLE_IDX = 31

get_photo(X[SAMPLE_IDX])
print(f"label of this photo: {y[SAMPLE_IDX]}")
# Out:
# label of this photo: 1

# %% [markdown]
# ## 1's are butterfly others are tree photos

# %%
SAMPLE_IDX = 33

get_photo(X[SAMPLE_IDX])
print(f"label of this photo: {y[SAMPLE_IDX]}")
# Out:
# label of this photo: 0

# %% [markdown]
# # CONTROL TRAIN_TEST_SPLITTER

# %%
from utils import train_test_splitter
X_train,X_test,y_train,y_test = train_test_splitter(X,y,0.1)

# %%
IDX = 13

get_photo(X_train[IDX])
print(f"label of this photo: {y_train[IDX]}")
# Out:
# label of this photo: 1

# %%
IDX = 831

get_photo(X_train[IDX])
print(f"label of this photo: {y_train[IDX]}")
# Out:
# label of this photo: 0

# %%
IDX = 12

get_photo(X_test[IDX])
print(f"label of this photo: {y_test[IDX]}")
# Out:
# label of this photo: 1

# %%
IDX = 13

get_photo(X_test[IDX])
print(f"label of this photo: {y_test[IDX]}")
# Out:
# label of this photo: 0
